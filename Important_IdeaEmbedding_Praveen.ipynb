# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenMishraJi/main/blob/main/Important_IdeaEmbedding_Praveen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install chromadb -q
# !pip install sentence-transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.1/448.1 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 22.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 46.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 28.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 60.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 8.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 38.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 6.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# Youtube Video: https://youtu.be/eCCHDxMaFIk

# %%
import chromadb

client = chromadb.Client()

collection = client.create_collection("idea_demo")

# %% [markdown]
# Default, Chroma uses the Sentence Transformers all-MiniLM-L6-v2 model to create embeddings.

# %%
collection.add(
    documents=["This is a document forest conservation", "This is a document trees implantation"],
    metadatas=[{"category": "forest"}, {"category": "trees"}],
    ids=["id1", "id2"]
)
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:03<00:00, 22.3MiB/s]

# %%
results = collection.query(
    query_texts=["how is leaf created"],
    n_results=1
)
results
# Out:
# {'ids': [['id2']],
#  'distances': [[1.3169631958007812]],
#  'metadatas': [[{'category': 'trees'}]],
#  'embeddings': None,
#  'documents': [['This is a document trees implantation']]}

# %%
import os

def read_files_from_folder(folder_path):
    file_data = []

    for file_name in os.listdir(folder_path):
        if file_name.endswith(".txt"):
            with open(os.path.join(folder_path, file_name), 'r') as file:
                content = file.read()
                file_data.append({"file_name": file_name, "content": content})

    return file_data

folder_path = "ideas"  #folder path
file_data = read_files_from_folder(folder_path)

#file_data.get("ideas")
for data in file_data:
    print(f"File Name: {data['file_name']}")
    print(f"Content: {data['content']}\n")
    #print(file_data)
# Out:
# File Name: Use natural beauty products.txt
# Content: Many beauty products contain harmful chemicals that can pollute the environment. Using natural beauty products can help reduce pollution.
#
# File Name: Paper production contributes to def.txt
# Content: Paper production contributes to deforestation and greenhouse gas emissions. Reducing paper usage at school by going digital or using recycled paper products can help reduce your carbon footprint.
#
# File Name: Reduce plastic packaging waste.txt
# Content: Many products come in excessive plastic packaging that ends up in landfills. Reducing plastic packaging waste by buying products with minimal packaging can help reduce waste.
#
# File Name: Use a reusable shopping bag.txt
# Content: Using a reusable shopping bag instead of disposable bags can help reduce waste and pollution.

# %%
documents = []
metadatas = []
ids = []
for index,data in enumerate(file_data):
  documents.append(data['content'])
  metadatas.append({'source':data['file_name']})
  ids.append(str(index+1))
  print(documents)
  print(metadatas)
  print(ids)
# Out:
# ['Many beauty products contain harmful chemicals that can pollute the environment. Using natural beauty products can help reduce pollution.']
# [{'source': 'Use natural beauty products.txt'}]
# ['1']
# ['Many beauty products contain harmful chemicals that can pollute the environment. Using natural beauty products can help reduce pollution.', 'Paper production contributes to deforestation and greenhouse gas emissions. Reducing paper usage at school by going digital or using recycled paper products can help reduce your carbon footprint.']
# [{'source': 'Use natural beauty products.txt'}, {'source': 'Paper production contributes to def.txt'}]
# ['1', '2']
# ...

# %%
metadatas
# Out:
# [{'source': 'Use natural beauty products.txt'},
#  {'source': 'Paper production contributes to def.txt'},
#  {'source': 'Reduce plastic packaging waste.txt'},
#  {'source': 'Use a reusable shopping bag.txt'}]

# %%
import chromadb
import chromadb.config
from chromadb.config import Settings
client = chromadb.PersistentClient(
    path="idea_db")

# %%
idea_collection = client.create_collection("idea_collection")
idea_collection.add(
    documents=documents,
    metadatas=metadatas,
    ids=ids
)

# %%
results = idea_collection.query(
    query_texts=["how to eyeliner and gloss"],
    n_results=1
)
results
# Out:
# {'ids': [['1']],
#  'distances': [[1.5720614729549387]],
#  'metadatas': [[{'source': 'Use natural beauty products.txt'}]],
#  'embeddings': None,
#  'documents': [['Many beauty products contain harmful chemicals that can pollute the environment. Using natural beauty products can help reduce pollution.']]}

# %%
results = idea_collection.query(
    query_texts=["What are the benefits of reducing throwing edibles?"],
    n_results=1,
    where_document={"$contains":"waste"}
)
results
# Out:
# {'ids': [['3']],
#  'distances': [[1.3527678284156253]],
#  'metadatas': [[{'source': 'Reduce plastic packaging waste.txt'}]],
#  'embeddings': None,
#  'documents': [['Many products come in excessive plastic packaging that ends up in landfills. Reducing plastic packaging waste by buying products with minimal packaging can help reduce waste.']]}

# %%
results = idea_collection.query(
    query_texts=["What are the emotional benefits of reducing plastic usage?"],
    n_results=1,
    where={"source": "Protect and Restore Natural Habitats.txt"},
    # where_document={"$contains":"habitat"}
)
results
# Out:
# {'ids': [[]],
#  'distances': [[]],
#  'metadatas': [[]],
#  'embeddings': None,
#  'documents': [[]]}

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('paraphrase-MiniLM-L3-v2')

# %%
documents = []
embeddings = []
metadatas = []
ids = []
for index,data in enumerate(file_data):
  documents.append(data['content'])
  embeding = model.encode(data['content']).tolist()
  embeddings.append(embeding)
  metadatas.append({'source':data['file_name']})
  ids.append(str(index+1))

# %%
ids
# Out:
# ['1', '2', '3', '4']

# %%
documents
# Out:
# ['Many beauty products contain harmful chemicals that can pollute the environment. Using natural beauty products can help reduce pollution.',
#  'Paper production contributes to deforestation and greenhouse gas emissions. Reducing paper usage at school by going digital or using recycled paper products can help reduce your carbon footprint.',
#  'Many products come in excessive plastic packaging that ends up in landfills. Reducing plastic packaging waste by buying products with minimal packaging can help reduce waste.',
#  'Using a reusable shopping bag instead of disposable bags can help reduce waste and pollution.\n']

# %%
idea_collection_emb = client.create_collection("idea_collection_emb")
idea_collection_emb.add(
    documents=documents,
    embeddings=embeddings,
    metadatas=metadatas,
    ids=ids
)

# %%
import numpy as np

# Function to calculate similarity score from L2 distance
def calculate_similarity(distance):
    # You can use a function like this to convert L2 distance to similarity percentage
    # You may need to adjust this formula depending on your specific requirements
    similarity_score = (1 / (1 + distance))*1000  # Adjust the formula as needed
    similarity_score = round(similarity_score, 2)
    return similarity_score

query = input("Please enter your suggestion: ")
input_em = model.encode(query).tolist()

# Perform the query using ChromaDB
results = idea_collection_emb.query(
    query_embeddings=[input_em],
    n_results=3,
    include=["distances", "metadatas", "documents"]
)

# Assuming that the 'results' dictionary contains distances, metadatas, and documents
distances = results.get("distances", [])
metadatas = results.get("metadatas", [])
documents = results.get("documents", [])

print(query)

# Check if distances are available and non-empty
if distances and len(distances[0]) > 0:
    # Combine distances, metadatas, and documents into tuples
    result_tuples = zip(distances[0], metadatas[0], documents[0])

    # Calculate similarity scores and sort the results by increasing distances
    sorted_results = sorted(result_tuples, key=lambda x: x[0], reverse=False)

    # Extract the sorted metadatas, documents, and similarity scores
    sorted_metadatas = [metadata for _, metadata, _ in sorted_results]
    sorted_documents = [document for _, _, document in sorted_results]
    similarity_scores = [calculate_similarity(distance) for distance, _, _ in sorted_results]

    # Print the sorted metadatas, documents, and similarity scores
    for i, (metadata, document, similarity_score) in enumerate(zip(sorted_metadatas, sorted_documents, similarity_scores), start=1):
        print(f"Result {i}:")
        print("Metadata:", metadata)
        print("Similarity Score: {}%".format(similarity_score))
        print("Document:", document)
        print()

else:
    print("No results found.")
# Out:
# Please enter your suggestion: What is phone case made of
# What is phone case made of
# Result 1:
# Metadata: {'source': 'Use a reusable shopping bag.txt'}
# Similarity Score: 25.78%
# Document: Using a reusable shopping bag instead of disposable bags can help reduce waste and pollution.
#
#
# Result 2:
# Metadata: {'source': 'Paper production contributes to def.txt'}
# Similarity Score: 23.41%
# Document: Paper production contributes to deforestation and greenhouse gas emissions. Reducing paper usage at school by going digital or using recycled paper products can help reduce your carbon footprint.
#
# Result 3:
# Metadata: {'source': 'Reduce plastic packaging waste.txt'}
# Similarity Score: 22.59%
# Document: Many products come in excessive plastic packaging that ends up in landfills. Reducing plastic packaging waste by buying products with minimal packaging can help reduce waste.

# %%
query = "What are the different environmental education?"
input_em = model.encode(query).tolist()

# Perform the query using ChromaDB
results = idea_collection_emb.query(
    query_embeddings=[input_em],
    n_results=3,
    include=["distances", "metadatas", "documents"]
)

# Assuming that the 'results' dictionary contains distances, metadatas, and documents
distances = results.get("distances", [])
metadatas = results.get("metadatas", [])
documents = results.get("documents", [])
print(query)
# Check if distances are available and non-empty
if distances and len(distances[0]) > 0:
    # Combine distances, metadatas, and documents into tuples
    result_tuples = zip(distances[0], metadatas[0], documents[0])

    # Sort the results by decreasing distances
    sorted_results = sorted(result_tuples, key=lambda x: x[0], reverse=False)

    # Extract the sorted metadatas and documents
    sorted_metadatas = [metadata for _, metadata, _ in sorted_results]
    sorted_documents = [document for _, _, document in sorted_results]

    # Print or use the sorted metadatas and documents
    print(sorted_metadatas)
    print(sorted_documents)
else:
    print("No results found.")
# Out:
# What are the different environmental education?
# [{'source': 'Paper production contributes to def.txt'}, {'source': 'Use natural beauty products.txt'}, {'source': 'Use a reusable shopping bag.txt'}]
# ['Paper production contributes to deforestation and greenhouse gas emissions. Reducing paper usage at school by going digital or using recycled paper products can help reduce your carbon footprint.', 'Many beauty products contain harmful chemicals that can pollute the environment. Using natural beauty products can help reduce pollution.', 'Using a reusable shopping bag instead of disposable bags can help reduce waste and pollution.\n']

# %%
query = "What are the different environmental education?"
input_em = model.encode(query).tolist()

results = idea_collection_emb.query(
    query_embeddings=[input_em],
    n_results=3,
)

# Print the structure of results
print(results)
# Out:
# {'ids': [['2', '1', '4']], 'distances': [[23.699217582962984, 30.362878633754416, 38.16820168856338]], 'metadatas': [[{'source': 'Paper production contributes to def.txt'}, {'source': 'Use natural beauty products.txt'}, {'source': 'Use a reusable shopping bag.txt'}]], 'embeddings': None, 'documents': [['Paper production contributes to deforestation and greenhouse gas emissions. Reducing paper usage at school by going digital or using recycled paper products can help reduce your carbon footprint.', 'Many beauty products contain harmful chemicals that can pollute the environment. Using natural beauty products can help reduce pollution.', 'Using a reusable shopping bag instead of disposable bags can help reduce waste and pollution.\n']]}

# %%
query = "What are the different environmental educatiion?"
input_em = model.encode(query).tolist()

results = idea_collection_emb.query(
    query_embeddings=[input_em],
    n_results=3,
    include = [ "distances", "metadatas" , "documents"]
)
import numpy as np

# Ensure that input_em is of type float64
input_em = np.array(input_em, dtype=np.float64)

# Calculate distances and create a list of (index, distance) tuples
distances = []
for index, emb in enumerate(idea_collection_emb):
    try:
        emb = np.array(emb, dtype=np.float64)  # Ensure that each embedding is of type float64
        distance = np.linalg.norm(input_em - emb)
        distances.append((index, distance))
    except (ValueError, TypeError):
        # Handle non-numeric embeddings or unexpected data types
        continue

# Sort results by distance in ascending order
sorted_results = sorted(distances, key=lambda x: x[1])

# Select the top N results
n_results = 3
top_results = sorted_results[:n_results]

# Extract and display the corresponding ideas or items
results = [idea_collection[index] for index, _ in top_results]
print(results)
# Out:
# []

# %%
collection.query(
    query_texts=["ideas/Advocate for Environmental Education.txt", "environmental education", "environmental issues"],
    n_results=2,
    where={"documents": "is_equal_to_this"},
    where_document={"$contains":"environment"}
)
# Out:
# {'ids': [[], [], []],
#  'distances': [[], [], []],
#  'metadatas': [[], [], []],
#  'embeddings': None,
#  'documents': [[], [], []]}

# %%
query = "what are different natural resources degradation"
input_em = model.encode(query).tolist()

results = idea_collection_emb.query(
    query_embeddings=[input_em],
    n_results=3 )

results
# Out:
# {'ids': [['1', '2', '3']],
#  'distances': [[31.973020767375406, 32.76057950868885, 36.637439864740365]],
#  'metadatas': [[{'source': 'Use natural beauty products.txt'},
#    {'source': 'Paper production contributes to def.txt'},
#    {'source': 'Reduce plastic packaging waste.txt'}]],
#  'embeddings': None,
#  'documents': [['Many beauty products contain harmful chemicals that can pollute the environment. Using natural beauty products can help reduce pollution.',
#    'Paper production contributes to deforestation and greenhouse gas emissions. Reducing paper usage at school by going digital or using recycled paper products can help reduce your carbon footprint.',
#    'Many products come in excessive plastic packaging that ends up in landfills. Reducing plastic packaging waste by buying products with minimal packaging can help reduce waste.']]}

# %%
idea_collection_emb.peek()
# Out:
# {'ids': ['1', '2', '3', '4'],
#  'embeddings': [[-0.08900925517082214,
#    0.051839232444763184,
#    -0.22000539302825928,
#    0.3154434561729431,
#    0.22074879705905914,
#    9.591629350325093e-05,
#    0.32192325592041016,
#    0.3279653489589691,
#    -0.12300495058298111,
#    0.24833039939403534,
#    0.16434048116207123,
#    -0.17938077449798584,
#    0.330020934343338,
#    0.06332636624574661,
#    -0.04098401963710785,
#    -0.24496690928936005,
#    -0.2393782138824463,
#    0.3533131778240204,
#    -0.3892160952091217,
#    0.06063219904899597,
#    0.01445153821259737,
#    0.26472458243370056,
#    -0.2542489171028137,
#    -0.22619925439357758,
#    -0.4039541780948639,
#    -0.20938487350940704,
#    -0.17436833679676056,
#    -0.24789661169052124,
#    -0.07869131118059158,
#    -0.017780562862753868,
#    0.2645290195941925,
#    0.19836361706256866,
#    -0.2579587399959564,
#    0.1803448647260666,
#    0.3898700475692749,
#    -0.024978553876280785,
# ...

# %%
# !zip -r 'idea_db.zip' 'idea_db'
# Out:
#   adding: idea_db/ (stored 0%)
#   adding: idea_db/chroma.sqlite3 (deflated 92%)
#   adding: idea_db/5d1e4de7-69dd-4916-9dc7-94f5ed00bca0/ (stored 0%)
#   adding: idea_db/5d1e4de7-69dd-4916-9dc7-94f5ed00bca0/data_level0.bin (deflated 8%)
#   adding: idea_db/5d1e4de7-69dd-4916-9dc7-94f5ed00bca0/link_lists.bin (stored 0%)
#   adding: idea_db/5d1e4de7-69dd-4916-9dc7-94f5ed00bca0/length.bin (deflated 82%)
#   adding: idea_db/5d1e4de7-69dd-4916-9dc7-94f5ed00bca0/header.bin (deflated 61%)
#   adding: idea_db/628e4748-512b-406f-a2ed-76cc5ca143be/ (stored 0%)
#   adding: idea_db/628e4748-512b-406f-a2ed-76cc5ca143be/data_level0.bin (deflated 47%)
#   adding: idea_db/628e4748-512b-406f-a2ed-76cc5ca143be/link_lists.bin (stored 0%)
#   adding: idea_db/628e4748-512b-406f-a2ed-76cc5ca143be/length.bin (deflated 80%)
#   adding: idea_db/628e4748-512b-406f-a2ed-76cc5ca143be/header.bin (deflated 61%)

# %%
import pandas as pd
file_named = input("Enter File Name : ")
#file_to_view = "ideas"
file_ext = pd.read_csv(f"ideas/{file_named}.txt")
file_ext
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-e21490558c3e> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 file_named = input("Enter File Name : ")
#       3 #file_to_view = "ideas"
#       4 file_ext = pd.read_csv(f"ideas/{file_named}.txt")
#       5 file_ext
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
import os

# Create the 'ideas' folder if it doesn't exist
if not os.path.exists('ideas'):
    os.makedirs('ideas')
process  = 'y'
# Get user inputs for title and content
while process ==  'y' :
  title = input("Enter the title for your idea: ")
  content = input("Enter the content for your idea: ")
  # Generate a unique filename based on the title
  filename = f'ideas/{title}.txt'

  # Create and write to the text file
  with open(filename, 'w') as file:
      file.write(f'{content}\n')

  print(f'Idea saved as "{filename}"')
  process = input("Enter 'y' to continue creeating and 'n' to stop process ")
else :
  print("Thank you folr ujsing the service")

# %%
{
  "sugg 1": {
    "title": "Dubai Sustainable Desert Safari",
    "category": "Tourism Innovation",
    "desc": "Introduce a sustainable desert safari experience in Dubai's pristine desert areas. Visitors can enjoy eco-friendly tours on electric vehicles, experience traditional Bedouin culture, and witness desert conservation efforts. This initiative will promote sustainable tourism, support local communities, and preserve the fragile desert ecosystem."
  },
  "sugg 2": {
    "title": "Green Energy Theme Park",
    "category": "Tourism Attraction",
    "desc": "Create a state-of-the-art theme park in Dubai dedicated to green energy and sustainability. Visitors can explore renewable energy installations, interactive exhibits, and learn about clean energy solutions. This innovative attraction will educate tourists, drive interest in sustainability, and boost tourism revenue."
  },
  "sugg 3": {
    "title": "Dubai Eco-Resorts",
    "category": "Hospitality",
    "desc": "Develop eco-friendly resorts along Dubai's coastline, featuring sustainable architecture, solar power, and water-saving technologies. These resorts will attract eco-conscious tourists, provide jobs, and set a global example for sustainable hospitality."
  },
  "sugg 4": {
    "title": "Marine Life Sanctuary",
    "category": "Conservation",
    "desc": "Establish a marine life sanctuary off Dubai's coast to protect endangered species and coral reefs. Visitors can explore the underwater world through eco-friendly tours, and research efforts can contribute to marine conservation. This initiative will bolster marine biodiversity, support scientific research, and attract marine enthusiasts."
  },
  "sugg 5": {
    "title": "Green Skyscraper Initiatives",
    "category": "Architecture",
    "desc": "Encourage architects and developers to create iconic green skyscrapers in Dubai. These buildings should incorporate vertical gardens, renewable energy systems, and sustainable materials. Not only will these skyscrapers redefine the skyline, but they'll also serve as models of eco-friendly urban development."
  },
  "sugg 6": {
    "title": "Dubai Eco-Cultural Festivals",
    "category": "Cultural Events",
    "desc": "Host annual eco-cultural festivals that showcase Dubai's rich heritage and commitment to sustainability. These festivals can feature traditional performances, eco-friendly crafts, and educational exhibits on conservation and green technologies. The festivals will celebrate culture, attract tourists, and promote environmental awareness."
  },
  "sugg 7": {
    "title": "Dubai Smart Transportation",
    "category": "Transportation Innovation",
    "desc": "Implement a smart transportation system in Dubai, featuring electric buses, autonomous vehicles, and efficient public transit options. This initiative will reduce traffic congestion, lower emissions, and enhance the tourist experience with seamless mobility."
  },
  "sugg 8": {
    "title": "Sustainable Souks and Markets",
    "category": "Retail",
    "desc": "Transform traditional souks and markets in Dubai into sustainable, eco-friendly shopping destinations. Vendors can sell locally sourced, handmade, and sustainable products. This will support local artisans, reduce carbon footprint, and provide unique shopping experiences for tourists."
  },
  "sugg 9": {
    "title": "Green Technology Incubators",
    "category": "Innovation",
    "desc": "Establish technology incubators in Dubai that focus on green innovations. These incubators will attract startups and entrepreneurs working on sustainable solutions, stimulating economic growth and fostering a culture of innovation."
  },
  "sugg 10": {
    "title": "Dubai Eco-Tourism Certification",
    "category": "Tourism Regulation",
    "desc": "Introduce a Dubai Eco-Tourism Certification program that assesses and certifies hotels, tour operators, and attractions based on their environmental and sustainability practices. This initiative will empower tourists to make eco-conscious choices and reward businesses committed to environmental responsibility."
  },
  "sugg 11": {
    "title": "Desert Greenhouses and Farms",
    "category": "Agriculture",
    "desc": "Establish eco-friendly greenhouses and farms in Dubai's desert using advanced technologies like vertical farming and hydroponics. These facilities can grow fresh produce sustainably and supply local restaurants, reducing the city's reliance on imported food."
  },
  "sugg 12": {
    "title": "Eco-Adventure Tours",
    "category": "Tourism Experience",
    "desc": "Offer eco-adventure tours that allow tourists to explore Dubai's natural beauty responsibly. Activities can include guided hikes, wildlife safaris, and desert conservation projects, providing unique experiences while fostering environmental awareness."
  },
  "sugg 13": {
    "title": "Dubai Solar Charging Stations",
    "category": "Infrastructure",
    "desc": "Install solar-powered charging stations for electric vehicles across the city. This infrastructure will support the transition to clean transportation, reduce emissions, and attract environmentally conscious tourists."
  },
  "sugg 14": {
    "title": "Marine Plastic Cleanup Initiative",
    "category": "Conservation",
    "desc": "Launch a program to clean up plastic waste from Dubai's beaches and waters. Engage volunteers, use eco-friendly equipment, and raise awareness about plastic pollution's impact on marine ecosystems."
  },
  "sugg 15": {
    "title": "Dubai Green Tech Expo",
    "category": "Technology Showcase",
    "desc": "Organize an annual Green Tech Expo in Dubai, showcasing the latest innovations in sustainable technology, renewable energy, and eco-friendly products. This event will attract global businesses and investors, driving economic growth in the green sector."
  },
  "sugg 16": {
    "title": "Sustainable Urban Design Competition",
    "category": "Architecture",
    "desc": "Host a competition for architects and urban planners to design sustainable neighborhoods and public spaces in Dubai. Winning designs can be implemented, creating eco-friendly urban areas that attract tourists and residents alike."
  },
  "sugg 17": {
    "title": "Wildlife Conservation Sanctuaries",
    "category": "Conservation",
    "desc": "Establish wildlife conservation sanctuaries in Dubai's natural reserves. These sanctuaries can protect endangered species, promote eco-tourism, and provide opportunities for scientific research."
  },
  "sugg 18": {
    "title": "Dubai Eco-Cruises",
    "category": "Tourism Innovation",
    "desc": "Offer eco-friendly cruises along Dubai's coastline, showcasing marine life and coastal beauty. These cruises can be powered by renewable energy sources and highlight Dubai's commitment to sustainable tourism."
  },
  "sugg 19": {
    "title": "Eco-Friendly Accommodations",
    "category": "Hospitality",
    "desc": "Encourage hotels and accommodations to adopt green practices such as energy-efficient lighting, water-saving measures, and waste reduction. Certify eco-friendly hotels to attract environmentally conscious tourists."
  },
  "sugg 20": {
    "title": "Dubai Green Tech Incubator",
    "category": "Innovation",
    "desc": "Establish a technology incubator focused on green and sustainable innovations. This hub can nurture startups working on clean energy, waste reduction, and sustainable transportation solutions, boosting Dubai's tech ecosystem."
  },
  "sugg 21": {
    "title": "Dubai Green Convention Center",
    "category": "Event Venue",
    "desc": "Construct a sustainable convention center in Dubai equipped with energy-efficient systems, green spaces, and eco-friendly event facilities. This center can host international conferences focused on sustainability and innovation, attracting global delegates and boosting the city's reputation."
  },
  "sugg 22": {
    "title": "Public Bicycle Sharing",
    "category": "Transportation Innovation",
    "desc": "Implement a citywide public bicycle sharing program in Dubai. Tourists and residents can easily rent bicycles to explore the city, reducing traffic congestion, emissions, and promoting a healthier lifestyle."
  },
  "sugg 23": {
    "title": "Dubai Solar Art Installation",
    "category": "Art and Culture",
    "desc": "Commission large-scale solar-powered art installations across the city. These captivating artworks can generate clean energy, serve as landmarks, and attract art enthusiasts and tourists interested in sustainable creativity."
  },
  "sugg 24": {
    "title": "Dubai Green Film Festival",
    "category": "Cultural Event",
    "desc": "Host an annual Green Film Festival showcasing documentaries and films that highlight environmental issues and solutions. This event can raise awareness, inspire positive action, and promote Dubai as a hub for eco-conscious cinema."
  },
  "sugg 25": {
    "title": "Sustainable Desert Resorts",
    "category": "Hospitality",
    "desc": "Develop luxury desert resorts in an environmentally sensitive manner. These resorts can offer unique desert experiences while adhering to sustainable construction practices, including minimal ecological impact and water conservation."
  },
  "sugg 26": {
    "title": "Dubai Eco-Friendly Souvenirs",
    "category": "Retail",
    "desc": "Encourage the production of eco-friendly souvenirs made from recycled materials or sustainable resources. Tourists can take home environmentally conscious keepsakes, supporting local artisans and reducing waste."
  },
  "sugg 27": {
    "title": "Green Roof Initiatives",
    "category": "Urban Development",
    "desc": "Promote the installation of green roofs on buildings across Dubai. Green roofs improve energy efficiency, reduce urban heat islands, and provide urban green spaces for residents and tourists to enjoy."
  },
  "sugg 28": {
    "title": "Dubai Waterfront Cleanup",
    "category": "Conservation",
    "desc": "Organize regular waterfront cleanup events along Dubai's coastlines, encouraging community participation and environmental stewardship. These efforts can enhance the city's natural beauty and protect marine ecosystems."
  },
  "sugg 29": {
    "title": "Eco-Friendly Transportation Hubs",
    "category": "Transportation Innovation",
    "desc": "Design and construct eco-friendly transportation hubs with green architecture, electric vehicle charging stations, and efficient public transit connections. These hubs can serve as sustainable gateways for tourists entering Dubai."
  },
  "sugg 30": {
    "title": "Dubai Eco-Tech Expo",
    "category": "Technology Showcase",
    "desc": "Host an annual Eco-Tech Expo featuring the latest sustainable technologies, eco-innovations, and green startups. This event can attract investors, entrepreneurs, and environmentally conscious consumers."
  },
  "sugg 31": {
    "title": "Dubai Eco-Friendly Theme Park",
    "category": "Tourism Attraction",
    "desc": "Create an eco-friendly theme park with rides and attractions that educate visitors about environmental conservation and sustainability. This unique park can serve as an engaging learning experience for tourists of all ages."
  },
  "sugg 32": {
    "title": "Dubai Wildlife Safari Lodges",
    "category": "Hospitality",
    "desc": "Develop wildlife safari lodges near Dubai's natural reserves, offering tourists the opportunity to stay close to nature. These lodges can adhere to sustainable practices and support wildlife conservation efforts."
  },
  "sugg 33": {
    "title": "Eco-Adventure Islands",
    "category": "Tourism Innovation",
    "desc": "Transform nearby islands into eco-adventure destinations, featuring activities like snorkeling, kayaking, and sustainable camping. These islands can be preserved and enhanced for nature-based tourism."
  },
  "sugg 34": {
    "title": "Dubai Sustainable Fashion Hub",
    "category": "Retail",
    "desc": "Establish a sustainable fashion hub in Dubai, showcasing eco-friendly clothing brands and designers. This hub can host fashion events, promote ethical fashion practices, and attract environmentally conscious shoppers."
  },
  "sugg 35": {
    "title": "Clean Energy Export Initiative",
    "category": "Trade",
    "desc": "Explore opportunities to export Dubai's excess clean energy to neighboring regions. This initiative can create additional revenue streams and position Dubai as a clean energy exporter."
  },
  "sugg 36": {
    "title": "Dubai Eco-Restaurant District",
    "category": "Culinary Innovation",
    "desc": "Designate a district in Dubai where all restaurants are committed to eco-friendly practices. These eateries can prioritize locally sourced ingredients, reduce food waste, and adopt sustainable culinary techniques."
  },
  "sugg 37": {
    "title": "Sustainable Urban Art Installations",
    "category": "Art and Culture",
    "desc": "Commission sustainable urban art installations throughout Dubai, incorporating recycled materials and emphasizing environmental messages. These artworks can serve as attractions for both tourists and residents."
  },
  "sugg 38": {
    "title": "Dubai Solar-Powered Water Desalination",
    "category": "Innovation",
    "desc": "Invest in solar-powered water desalination facilities to provide clean and sustainable freshwater sources for Dubai's growing population. This technology can also be showcased as an innovative solution to global water scarcity."
  },
  "sugg 39": {
    "title": "Green Event Venues",
    "category": "Event Spaces",
    "desc": "Transform event venues in Dubai into eco-friendly spaces with energy-efficient lighting, waste reduction practices, and sustainable event hosting. This approach can attract green-minded event organizers and attendees."
  },
  "sugg 40": {
    "title": "Dubai Environmental Education Centers",
    "category": "Education",
    "desc": "Establish environmental education centers across Dubai, offering interactive exhibits, workshops, and programs on sustainability, biodiversity, and conservation. These centers can be valuable resources for both tourists and residents."
  },
  "sugg 41": {
    "title": "Dubai Green Tech Park",
    "category": "Innovation",
    "desc": "Create a dedicated Green Tech Park in Dubai where tech companies, researchers, and startups can collaborate on sustainable innovations. This innovation hub can attract investments and position Dubai as a leader in green technology."
  },
  "sugg 42": {
    "title": "Dubai Sustainable Transport Expo",
    "category": "Event",
    "desc": "Host an annual Sustainable Transport Expo that showcases eco-friendly transportation solutions, electric vehicles, and green infrastructure. This event can attract industry leaders, investors, and tourists interested in sustainable mobility."
  },
  "sugg 43": {
    "title": "Eco-Friendly Cruises to The World Islands",
    "category": "Tourism Attraction",
    "desc": "Launch eco-friendly cruises that take tourists to The World Islands, a collection of artificial islands. These tours can focus on marine conservation, underwater exploration, and sustainable tourism practices."
  },
  "sugg 44": {
    "title": "Dubai Recycling Innovation Center",
    "category": "Innovation",
    "desc": "Establish a Recycling Innovation Center in Dubai that focuses on advanced recycling technologies, waste reduction strategies, and the development of sustainable materials. This center can drive innovation and attract green businesses."
  },
  "sugg 45": {
    "title": "Dubai Carbon Offset Program",
    "category": "Climate Action",
    "desc": "Implement a citywide carbon offset program, where businesses and individuals can invest in local environmental projects to offset their carbon emissions. This initiative can fund sustainability initiatives and raise awareness."
  },
  "sugg 46": {
    "title": "Eco-Friendly Shopping District",
    "category": "Retail",
    "desc": "Designate a shopping district in Dubai that exclusively features eco-friendly and sustainable products. This district can cater to tourists seeking responsible shopping options."
  },
  "sugg 47": {
    "title": "Dubai Eco-Tourism Scholarships",
    "category": "Education",
    "desc": "Create scholarships for students pursuing degrees in environmental science, tourism management, and sustainability. Encourage young talent to contribute to Dubai's sustainable tourism sector."
  },
  "sugg 48": {
    "title": "Sustainable Desert Sports Complex",
    "category": "Sports and Recreation",
    "desc": "Develop a desert sports complex where tourists can enjoy activities like sandboarding, dune bashing, and camel racing in an eco-friendly manner. Emphasize minimal environmental impact and preservation of desert ecosystems."
  },
  "sugg 49": {
    "title": "Dubai Green Film Studio",
    "category": "Entertainment",
    "desc": "Establish a green film studio in Dubai that offers state-of-the-art facilities for eco-conscious filmmakers. Attract international film productions that prioritize sustainability and environmental responsibility."
  },
  "sugg 50": {
    "title": "Dubai Sustainable Tourism Awards",
    "category": "Tourism Recognition",
    "desc": "Introduce annual Sustainable Tourism Awards to recognize and reward businesses, hotels, and initiatives in Dubai that demonstrate outstanding commitment to environmental sustainability in the tourism sector."
  },
  "sugg 51": {
    "title": "Dubai Green Music Festival",
    "category": "Cultural Event",
    "desc": "Organize an annual Green Music Festival featuring eco-friendly stages, sustainable food vendors, and performances by artists dedicated to environmental causes. This festival can raise awareness about sustainability through the power of music and entertainment."
  },
  "sugg 52": {
    "title": "Eco-Tours of Dubai's Mangroves",
    "category": "Tourism Experience",
    "desc": "Offer guided eco-tours of Dubai's mangroves, highlighting their importance as natural buffers and habitats. These tours can educate tourists about coastal ecosystems and the need for mangrove conservation."
  },
  "sugg 53": {
    "title": "Dubai Green Certification Program",
    "category": "Business Recognition",
    "desc": "Launch a Dubai Green Certification Program for businesses that adhere to sustainable practices. Certified businesses can display eco-friendly logos, attracting eco-conscious consumers and contributing to a greener economy."
  },
  "sugg 54": {
    "title": "Solar-Powered Desert Art Installations",
    "category": "Art and Culture",
    "desc": "Commission a series of solar-powered art installations in Dubai's desert. These pieces can generate clean energy during the day and create captivating light displays at night, showcasing the fusion of art and sustainability."
  },
  "sugg 55": {
    "title": "Dubai Green Trade Show",
    "category": "Trade",
    "desc": "Host an annual Green Trade Show that brings together sustainable businesses, green products, and eco-innovations. This event can attract international buyers, fostering eco-friendly trade and investments."
  },
  "sugg 56": {
    "title": "Eco-Friendly Desert Camps",
    "category": "Hospitality",
    "desc": "Establish eco-friendly desert camps that offer tourists an immersive and sustainable desert experience. These camps can focus on low-impact tourism, renewable energy use, and desert conservation."
  },
  "sugg 57": {
    "title": "Dubai Environmental Research Institute",
    "category": "Research",
    "desc": "Establish a world-class Environmental Research Institute in Dubai, focusing on climate change, desert ecology, and sustainable technologies. This institute can attract top researchers, drive innovation, and enhance the city's reputation."
  },
  "sugg 58": {
    "title": "Dubai Green Roof Initiative",
    "category": "Urban Development",
    "desc": "Implement incentives and regulations for green roofs on commercial and residential buildings in Dubai. Green roofs can provide insulation, reduce energy consumption, and create urban green spaces."
  },
  "sugg 59": {
    "title": "Sustainable Souvenir Workshops",
    "category": "Tourism Experience",
    "desc": "Organize workshops where tourists can create their own sustainable souvenirs using recycled materials. These hands-on experiences promote creativity and environmental responsibility."
  },
  "sugg 60": {
    "title": "Dubai Eco-Tourism Mobile App",
    "category": "Technology Innovation",
    "desc": "Develop a mobile app that provides tourists with eco-friendly travel tips, guides to sustainable attractions, and real-time information on public transportation. Enhance the visitor experience while promoting eco-conscious choices."
  },
  "sugg 61": {
    "title": "Dubai Green Transportation Expo",
    "category": "Event",
    "desc": "Host an annual Green Transportation Expo showcasing eco-friendly vehicles, electric scooters, and sustainable transportation solutions. This event can attract manufacturers, investors, and tourists interested in green mobility."
  },
  "sugg 62": {
    "title": "Sustainable Fashion Week",
    "category": "Fashion Industry",
    "desc": "Organize a Sustainable Fashion Week in Dubai featuring runway shows, eco-friendly clothing collections, and discussions on ethical fashion. Attract fashion designers, influencers, and eco-conscious consumers."
  },
  "sugg 63": {
    "title": "Dubai Eco-Tourism Workshops",
    "category": "Education",
    "desc": "Offer eco-tourism workshops for tourists to learn about sustainable practices while exploring Dubai. These workshops can include wildlife conservation, desert preservation, and responsible travel tips."
  },
  "sugg 64": {
    "title": "Dubai Waterfront Eco-Parks",
    "category": "Urban Development",
    "desc": "Transform sections of Dubai's waterfront into eco-parks with green spaces, wildlife habitats, and walking trails. These urban oases can provide relaxation spots for tourists and residents while enhancing biodiversity."
  },
  "sugg 65": {
    "title": "Solar-Powered Floating Hotels",
    "category": "Hospitality",
    "desc": "Introduce solar-powered floating hotels on Dubai's water bodies, offering guests a unique and eco-friendly stay. These floating accommodations can operate sustainably and contribute to Dubai's tourism appeal."
  },
  "sugg 66": {
    "title": "Dubai Environmental Art Festival",
    "category": "Cultural Event",
    "desc": "Host an Environmental Art Festival that features environmentally themed art installations, performances, and workshops. This festival can promote environmental awareness through creative expression."
  },
  "sugg 67": {
    "title": "Eco-Friendly Urban Transportation",
    "category": "Transportation Innovation",
    "desc": "Invest in eco-friendly urban transportation options such as electric buses, bicycle lanes, and pedestrian-friendly streets. Enhance urban mobility while reducing emissions and congestion."
  },
  "sugg 68": {
    "title": "Dubai Green Tech Investment Fund",
    "category": "Investment",
    "desc": "Establish a Dubai Green Tech Investment Fund to support startups and businesses working on sustainable technologies. Attract investments and position Dubai as a hub for green innovation."
  },
  "sugg 69": {
    "title": "Eco-Tourism Wildlife Rehabilitation Center",
    "category": "Conservation",
    "desc": "Create a wildlife rehabilitation center focusing on the rescue, rehabilitation, and release of injured or endangered animals. Educate tourists about conservation efforts while providing a safe haven for wildlife."
  },
  "sugg 70": {
    "title": "Dubai Eco-Friendly Transportation App",
    "category": "Technology Innovation",
    "desc": "Develop a dedicated eco-friendly transportation app for tourists and residents. This app can provide real-time information on green transit options, carpooling, and bike-sharing services."
  },
  "sugg 71": {
    "title": "Dubai Sustainable Energy Park",
    "category": "Innovation",
    "desc": "Establish a Sustainable Energy Park in Dubai where visitors can learn about renewable energy sources, view solar and wind power installations, and participate in eco-energy workshops. This park can inspire sustainable energy adoption."
  },
  "sugg 72": {
    "title": "Eco-Friendly Golf Courses",
    "category": "Recreation",
    "desc": "Transform golf courses in Dubai into eco-friendly facilities with water-efficient irrigation, native landscaping, and wildlife conservation zones. Promote responsible golfing practices."
  },
  "sugg 73": {
    "title": "Dubai Plastic-Free Initiative",
    "category": "Environmental Awareness",
    "desc": "Launch a citywide campaign to reduce single-use plastic consumption. Encourage businesses to offer sustainable alternatives and educate tourists about the environmental impact of plastics."
  },
  "sugg 74": {
    "title": "Dubai Sustainable Seafood Restaurants",
    "category": "Culinary Innovation",
    "desc": "Promote sustainable seafood practices in Dubai's restaurants. Certify eateries that serve responsibly sourced seafood, conserving marine ecosystems while offering delicious cuisine."
  },
  "sugg 75": {
    "title": "Eco-Tourism Cultural Villages",
    "category": "Tourism Experience",
    "desc": "Create cultural villages where tourists can immerse themselves in sustainable practices of Dubai's heritage. These villages can showcase traditional eco-friendly techniques and crafts."
  },
  "sugg 76": {
    "title": "Dubai Green Innovation Awards",
    "category": "Recognition",
    "desc": "Institute annual Green Innovation Awards in Dubai to honor businesses, startups, and individuals pioneering sustainable solutions. Recognize and celebrate contributions to environmental progress."
  },
  "sugg 77": {
    "title": "Dubai Sustainable Transportation Tours",
    "category": "Tourism Experience",
    "desc": "Offer guided sustainable transportation tours where tourists can experience eco-friendly modes of travel, including electric vehicles, cycling, and public transit."
  },
  "sugg 78": {
    "title": "Eco-Friendly Dive Centers",
    "category": "Tourism Attraction",
    "desc": "Establish eco-friendly dive centers along Dubai's coast, providing tourists with opportunities to explore marine life responsibly. Emphasize marine conservation and eco-awareness during dives."
  },
  "sugg 79": {
    "title": "Dubai E-Waste Recycling Drive",
    "category": "Environmental Action",
    "desc": "Organize regular e-waste recycling drives in Dubai, encouraging residents and tourists to dispose of electronic waste responsibly. Safely recycle and repurpose electronic devices."
  },
  "sugg 80": {
    "title": "Sustainable Dubai Tourist Map",
    "category": "Technology Innovation",
    "desc": "Develop an interactive tourist map that highlights eco-friendly attractions, green hotels, and sustainable dining options. Provide tourists with a convenient guide to responsible exploration."
  },
  "sugg 81": {
    "title": "Dubai Sustainable Adventure Parks",
    "category": "Tourism Attraction",
    "desc": "Develop adventure parks with eco-friendly activities such as zip-lining, rope courses, and nature trails. These parks can blend adventure with environmental education."
  },
  "sugg 82": {
    "title": "Eco-Friendly Marina Developments",
    "category": "Urban Development",
    "desc": "Design marina developments with sustainability in mind. Implement eco-friendly dock construction, renewable energy sources, and waterway preservation efforts."
  },
  "sugg 83": {
    "title": "Dubai Green Culinary Tours",
    "category": "Tourism Experience",
    "desc": "Offer culinary tours that introduce tourists to Dubai's eco-friendly dining scene. Explore farm-to-table restaurants, organic markets, and sustainable food production."
  },
  "sugg 84": {
    "title": "Dubai Wildlife Conservation Education Center",
    "category": "Conservation",
    "desc": "Establish a wildlife conservation education center where visitors can learn about local flora and fauna. Promote conservation and support research initiatives."
  },
  "sugg 85": {
    "title": "Sustainable Dubai Art District",
    "category": "Art and Culture",
    "desc": "Create an art district that features sustainable art installations, recycled materials, and eco-conscious exhibits. Blend creativity with environmental awareness."
  },
  "sugg 86": {
    "title": "Dubai Green Shipping Hub",
    "category": "Trade",
    "desc": "Develop a green shipping hub in Dubai's ports, promoting eco-friendly shipping practices, vessel designs, and sustainable cargo handling."
  },
  "sugg 87": {
    "title": "Eco-Tourism Photography Workshops",
    "category": "Tourism Experience",
    "desc": "Offer eco-tourism photography workshops that teach tourists how to capture the beauty of Dubai's natural landscapes while promoting environmental awareness."
  },
  "sugg 88": {
    "title": "Dubai Sustainable Fashion Incubator",
    "category": "Fashion Industry",
    "desc": "Establish a fashion incubator for sustainable designers to innovate eco-friendly clothing and accessories. Attract eco-conscious designers and support their creative endeavors."
  },
  "sugg 89": {
    "title": "Green Technology Research Grants",
    "category": "Innovation",
    "desc": "Provide research grants for green technology startups and academic institutions. Fund innovative projects that contribute to Dubai's sustainable future."
  },
  "sugg 90": {
    "title": "Dubai Eco-Heritage Tours",
    "category": "Tourism Experience",
    "desc": "Introduce eco-heritage tours that combine cultural heritage exploration with environmental preservation. Showcase traditional practices that align with sustainable living."
  },
  "sugg 91": {
    "title": "Dubai Green Infrastructure Projects",
    "category": "Urban Development",
    "desc": "Invest in green infrastructure projects such as urban parks, vertical gardens, and green roofs across Dubai. Enhance the city's aesthetics, air quality, and overall well-being."
  },
  "sugg 92": {
    "title": "Eco-Friendly Desert Safaris",
    "category": "Tourism Attraction",
    "desc": "Revamp desert safari experiences with eco-friendly vehicles, guided tours on desert ecology, and sustainable camping practices. Highlight the importance of preserving the desert ecosystem."
  },
  "sugg 93": {
    "title": "Dubai Eco-Tech Incubator",
    "category": "Innovation",
    "desc": "Establish an eco-tech incubator that supports startups working on green technologies, renewable energy solutions, and environmental innovations. Foster innovation and entrepreneurship."
  },
  "sugg 94": {
    "title": "Sustainable Cultural Festivals",
    "category": "Cultural Events",
    "desc": "Organize cultural festivals in Dubai that celebrate diversity, sustainability, and eco-conscious practices. These events can promote cultural exchange while highlighting environmental values."
  },
  "sugg 95": {
    "title": "Dubai Zero-Waste Markets",
    "category": "Retail",
    "desc": "Create zero-waste markets where consumers can shop for products with minimal packaging. Encourage sustainable shopping habits and reduce plastic waste."
  },
  "sugg 96": {
    "title": "Dubai Green Tourism Certification",
    "category": "Business Recognition",
    "desc": "Introduce a Green Tourism Certification program for hotels and tourist attractions. Recognize businesses that implement sustainable practices, encouraging responsible tourism."
  },
  "sugg 97": {
    "title": "Eco-Friendly Sports Complexes",
    "category": "Sports and Recreation",
    "desc": "Develop sports complexes that incorporate sustainable features like energy-efficient lighting, rainwater harvesting, and green landscaping. Promote green sports and recreation facilities."
  },
  "sugg 98": {
    "title": "Dubai Climate Education Center",
    "category": "Education",
    "desc":"Establish a Climate Education Center that educates students, tourists, and residents about climate change, its impacts, and sustainable solutions. Promote climate literacy."
  },
  "sugg 99": {
    "title": "Dubai Green Bookstores",
    "category": "Retail",
    "desc": "Support the creation of green bookstores that focus on sustainability, environmental literature, and eco-conscious reading materials. Foster a love for green literature."
  },
  "sugg 100": {
    "title": "Dubai Eco-Tourism Expo",
    "category": "Event",
    "desc": "Host an annual Eco-Tourism Expo featuring eco-conscious travel destinations, sustainable travel companies, and responsible tourism practices. Attract eco-minded tourists and industry professionals."
  }
}
